# %%
import numpy as np
import pandas as pd
import tensorflow as tf

# =========================
# Load Dataset
# =========================

df = pd.read_csv("Churn_Modelling.csv")

print("Columns in dataset:")
print(df.columns.tolist())

# =========================
# Drop unnecessary columns
# =========================

cols_to_drop = ['RowNumber', 'CustomerId', 'Surname']

for col in cols_to_drop:
    if col in df.columns:
        df.drop(col, axis=1, inplace=True)

print("\nColumns after dropping:")
print(df.columns.tolist())

# =========================
# Encode categorical data
# =========================

from sklearn.preprocessing import LabelEncoder

le_geo = LabelEncoder()
le_gender = LabelEncoder()

if 'Geography' in df.columns:
    df['Geography'] = le_geo.fit_transform(df['Geography'])

if 'Gender' in df.columns:
    df['Gender'] = le_gender.fit_transform(df['Gender'])

# =========================
# Features and Target
# =========================

X = df.drop('Exited', axis=1)
y = df['Exited']

# =========================
# Split Dataset
# =========================

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.2,
    random_state=0
)

# =========================
# Feature Scaling
# =========================

from sklearn.preprocessing import StandardScaler

sc = StandardScaler()

X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# =========================
# Build ANN
# =========================

ann = tf.keras.models.Sequential()

ann.add(tf.keras.layers.Dense(units=6, activation='relu'))
ann.add(tf.keras.layers.Dense(units=6, activation='relu'))
ann.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# =========================
# Compile ANN
# =========================

ann.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# =========================
# Callbacks
# =========================

early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=10,
    restore_best_weights=True
)

reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.2,
    patience=10,
    min_lr=0.0001
)

# =========================
# Train ANN
# =========================

history = ann.fit(
    X_train,
    y_train,
    batch_size=32,
    epochs=100,
    validation_data=(X_test, y_test),
    callbacks=[early_stopping, reduce_lr]
)

# =========================
# Single Prediction
# =========================

sample = pd.DataFrame(
    [[600, 0, 1, 40, 3, 60000, 2, 1, 1, 50000]],
    columns=X.columns
)

sample_scaled = sc.transform(sample)

prediction = ann.predict(sample_scaled)

print("\nPrediction Probability:", prediction[0][0])

if prediction[0][0] > 0.5:
    print("Customer will leave the bank")
else:
    print("Customer will stay in the bank")

# =========================
# Test Predictions
# =========================

y_pred = ann.predict(X_test)
y_pred = (y_pred > 0.5)

# =========================
# Evaluation
# =========================

from sklearn.metrics import (
    confusion_matrix,
    accuracy_score,
    classification_report,
    precision_score,
    recall_score,
    roc_auc_score
)

print("\nClassification Report")
print(classification_report(y_test, y_pred))

cm = confusion_matrix(y_test, y_pred)

print("\nConfusion Matrix")
print(cm)

print("\nAccuracy")
print(accuracy_score(y_test, y_pred))

# =========================
# Detailed Metrics
# =========================

train_loss, train_acc = ann.evaluate(X_train, y_train, verbose=0)
test_loss, test_acc = ann.evaluate(X_test, y_test, verbose=0)

y_train_pred = ann.predict(X_train)
train_auc = roc_auc_score(y_train, y_train_pred)

y_test_pred = ann.predict(X_test)
test_auc = roc_auc_score(y_test, y_test_pred)

print("\nTraining Accuracy:", train_acc)
print("Test Accuracy:", test_acc)
print("Test AUC:", test_auc)

# =========================
# Plot Accuracy & Loss
# =========================

import matplotlib.pyplot as plt

plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'])

plt.subplot(1,2,2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'])

plt.show()
# Out:
# Columns in dataset:
# ['RowNumber', 'CustomerId', 'CreditScore', 'Geography', 'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary', 'Exited']
#
# Columns after dropping:
# ['CreditScore', 'Geography', 'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary', 'Exited']
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Epoch 1/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.6145 - loss: 0.7228 - val_accuracy: 0.7805 - val_loss: 0.5363 - learning_rate: 0.0010
# Epoch 2/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7961 - loss: 0.5116 - val_accuracy: 0.7980 - val_loss: 0.4781 - learning_rate: 0.0010
# Epoch 3/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8010 - loss: 0.4751 - val_accuracy: 0.8055 - val_loss: 0.4535 - learning_rate: 0.0010
# Epoch 4/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8049 - loss: 0.4537 - val_accuracy: 0.8115 - val_loss: 0.4366 - learning_rate: 0.0010
# Epoch 5/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8120 - loss: 0.4362 - val_accuracy: 0.8245 - val_loss: 0.4189 - learning_rate: 0.0010
# Epoch 6/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8242 - loss: 0.4179 - val_accuracy: 0.8395 - val_loss: 0.4001 - learning_rate: 0.0010
# Epoch 7/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8344 - loss: 0.4003 - val_accuracy: 0.8480 - val_loss: 0.3851 - learning_rate: 0.0010
# Epoch 8/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8422 - loss: 0.3869 - val_accuracy: 0.8530 - val_loss: 0.3736 - learning_rate: 0.0010
# Epoch 9/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8469 - loss: 0.3770 - val_accuracy: 0.8560 - val_loss: 0.3662 - learning_rate: 0.0010
# Epoch 10/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8486 - loss: 0.3703 - val_accuracy: 0.8540 - val_loss: 0.3607 - learning_rate: 0.0010
# Epoch 11/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8516 - loss: 0.3648 - val_accuracy: 0.8610 - val_loss: 0.3569 - learning_rate: 0.0010
# Epoch 12/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8524 - loss: 0.3608 - val_accuracy: 0.8630 - val_loss: 0.3542 - learning_rate: 0.0010
# Epoch 13/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8533 - loss: 0.3583 - val_accuracy: 0.8605 - val_loss: 0.3513 - learning_rate: 0.0010
# Epoch 14/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8534 - loss: 0.3560 - val_accuracy: 0.8605 - val_loss: 0.3488 - learning_rate: 0.0010
# Epoch 15/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8551 - loss: 0.3545 - val_accuracy: 0.8615 - val_loss: 0.3477 - learning_rate: 0.0010
# Epoch 16/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8560 - loss: 0.3527 - val_accuracy: 0.8610 - val_loss: 0.3452 - learning_rate: 0.0010
# Epoch 17/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8562 - loss: 0.3517 - val_accuracy: 0.8635 - val_loss: 0.3444 - learning_rate: 0.0010
# Epoch 18/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8571 - loss: 0.3506 - val_accuracy: 0.8610 - val_loss: 0.3428 - learning_rate: 0.0010
# Epoch 19/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8583 - loss: 0.3498 - val_accuracy: 0.8625 - val_loss: 0.3430 - learning_rate: 0.0010
# Epoch 20/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8571 - loss: 0.3490 - val_accuracy: 0.8640 - val_loss: 0.3428 - learning_rate: 0.0010
# Epoch 21/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8571 - loss: 0.3483 - val_accuracy: 0.8635 - val_loss: 0.3425 - learning_rate: 0.0010
# Epoch 22/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8589 - loss: 0.3474 - val_accuracy: 0.8640 - val_loss: 0.3415 - learning_rate: 0.0010
# Epoch 23/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8579 - loss: 0.3471 - val_accuracy: 0.8635 - val_loss: 0.3415 - learning_rate: 0.0010
# Epoch 24/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8580 - loss: 0.3465 - val_accuracy: 0.8625 - val_loss: 0.3406 - learning_rate: 0.0010
# Epoch 25/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8579 - loss: 0.3464 - val_accuracy: 0.8640 - val_loss: 0.3413 - learning_rate: 0.0010
# Epoch 26/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8583 - loss: 0.3458 - val_accuracy: 0.8630 - val_loss: 0.3409 - learning_rate: 0.0010
# Epoch 27/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8577 - loss: 0.3453 - val_accuracy: 0.8635 - val_loss: 0.3413 - learning_rate: 0.0010
# Epoch 28/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8593 - loss: 0.3450 - val_accuracy: 0.8630 - val_loss: 0.3413 - learning_rate: 0.0010
# Epoch 29/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8576 - loss: 0.3448 - val_accuracy: 0.8620 - val_loss: 0.3401 - learning_rate: 0.0010
# Epoch 30/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8577 - loss: 0.3442 - val_accuracy: 0.8640 - val_loss: 0.3413 - learning_rate: 0.0010
# Epoch 31/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8586 - loss: 0.3441 - val_accuracy: 0.8625 - val_loss: 0.3397 - learning_rate: 0.0010
# Epoch 32/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8580 - loss: 0.3439 - val_accuracy: 0.8620 - val_loss: 0.3400 - learning_rate: 0.0010
# Epoch 33/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8583 - loss: 0.3436 - val_accuracy: 0.8615 - val_loss: 0.3401 - learning_rate: 0.0010
# Epoch 34/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8589 - loss: 0.3436 - val_accuracy: 0.8630 - val_loss: 0.3405 - learning_rate: 0.0010
# Epoch 35/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8580 - loss: 0.3431 - val_accuracy: 0.8620 - val_loss: 0.3403 - learning_rate: 0.0010
# Epoch 36/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8579 - loss: 0.3428 - val_accuracy: 0.8625 - val_loss: 0.3402 - learning_rate: 0.0010
# Epoch 37/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8590 - loss: 0.3427 - val_accuracy: 0.8635 - val_loss: 0.3416 - learning_rate: 0.0010
# Epoch 38/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8593 - loss: 0.3423 - val_accuracy: 0.8630 - val_loss: 0.3392 - learning_rate: 0.0010
# Epoch 39/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8589 - loss: 0.3421 - val_accuracy: 0.8625 - val_loss: 0.3397 - learning_rate: 0.0010
# Epoch 40/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8579 - loss: 0.3422 - val_accuracy: 0.8620 - val_loss: 0.3393 - learning_rate: 0.0010
# Epoch 41/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8583 - loss: 0.3418 - val_accuracy: 0.8640 - val_loss: 0.3410 - learning_rate: 0.0010
# Epoch 42/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8590 - loss: 0.3416 - val_accuracy: 0.8640 - val_loss: 0.3409 - learning_rate: 0.0010
# Epoch 43/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8583 - loss: 0.3415 - val_accuracy: 0.8620 - val_loss: 0.3400 - learning_rate: 0.0010
# Epoch 44/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8585 - loss: 0.3412 - val_accuracy: 0.8620 - val_loss: 0.3400 - learning_rate: 0.0010
# Epoch 45/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8601 - loss: 0.3410 - val_accuracy: 0.8655 - val_loss: 0.3433 - learning_rate: 0.0010
# Epoch 46/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8587 - loss: 0.3410 - val_accuracy: 0.8635 - val_loss: 0.3402 - learning_rate: 0.0010
# Epoch 47/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8602 - loss: 0.3408 - val_accuracy: 0.8635 - val_loss: 0.3407 - learning_rate: 0.0010
# Epoch 48/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8605 - loss: 0.3406 - val_accuracy: 0.8640 - val_loss: 0.3402 - learning_rate: 0.0010
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
#
# Prediction Probability: 0.02634719
# Customer will stay in the bank
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 860us/step
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.88      0.96      0.92      1595
#            1       0.77      0.47      0.58       405
#
#     accuracy                           0.86      2000
#    macro avg       0.82      0.72      0.75      2000
# weighted avg       0.85      0.86      0.85      2000
#
#
# Confusion Matrix
# [[1537   58]
#  [ 216  189]]
#
# Accuracy
# 0.863
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 679us/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 893us/step
#
# Training Accuracy: 0.859624981880188
# Test Accuracy: 0.8629999756813049
# Test AUC: 0.8607299044080653
